# %%
import numpy as np
import pandas as pd
import json

with open('recipes_with_nutritional_info.json') as f:
    data = json.loads(f.read())
    
df = pd.json_normalize(data)
df.head()
# Out:
#            id                                        ingredients  \
# 0  000095fc1d  [{'text': 'yogurt, greek, plain, nonfat'}, {'t...
# 1  00051d5b9d  [{'text': 'sugars, granulated'}, {'text': 'oil...
# 2  00059b093b  [{'text': 'chicken, broilers or fryers, wing, ...
# 3  0005fc89f7  [{'text': 'crustaceans, shrimp, raw (not previ...
# 4  0006ca31f4  [{'text': 'cocoa, dry powder, unsweetened'}, {...
#
#                                         instructions  \
# 0  [{'text': 'Layer all ingredients in a serving ...
# 1  [{'text': 'Cream sugar and butter together til...
# 2  [{'text': 'Preheat oven to 400 degrees F.'}, {...
# 3  [{'text': 'In a large bowl, toss the shrimp, g...
# 4  [{'text': 'Measure out the cocoa powder into a...
#
#                                  nutr_per_ingredient partition  \
# 0  [{'fat': 0.8845044000000001, 'nrg': 133.80964,...     train
# 1  [{'fat': 0.0, 'nrg': 384.0, 'pro': 0.0, 'sat':...       val
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51235 entries, 0 to 51234
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             51235 non-null  object
#  1   ingredients                    51235 non-null  object
#  2   instructions                   51235 non-null  object
#  3   nutr_per_ingredient            51235 non-null  object
#  4   partition                      51235 non-null  object
#  5   quantity                       51235 non-null  object
#  6   title                          51235 non-null  object
#  7   unit                           51235 non-null  object
#  8   url                            51235 non-null  object
#  9   weight_per_ingr                51235 non-null  object
#  10  fsa_lights_per100g.fat         51235 non-null  object
#  11  fsa_lights_per100g.salt        51235 non-null  object
# ...
